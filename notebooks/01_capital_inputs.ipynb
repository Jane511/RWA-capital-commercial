# %% [markdown]
# # 01 Capital Inputs
#
# Inspect the combined capital input snapshot before the RWA engine runs.
#
# Focus on facility descriptors, PD, LGD, EAD, expected loss, stressed loss, and the monitoring joins that enrich the capital view.

# %%
from src.run_pipeline import run_pipeline

result = run_pipeline(persist=False, refresh_demo_inputs=True)
result["combined_inputs"].head()
