# %% [markdown]
# # 04 Capital Ratios
# Summarise total RWA and calculate CET1 and total capital ratios.

# %%
from src.calculate_el import add_expected_loss
from src.calculate_rwa import add_rwa_metrics
from src.capital_ratios import build_capital_ratio_summary
from src.merge_inputs import build_capital_input

capital_input, capital_structure = build_capital_input(refresh_demo=True)
exposure_level = add_rwa_metrics(add_expected_loss(capital_input))
build_capital_ratio_summary(exposure_level, capital_structure)
