# %% [markdown]
# # 05 Stress Testing
# Run the base case and the single stressed scenario from the instruction PDF.

# %%
from src.merge_inputs import build_capital_input
from src.stress_testing import run_stress_test

capital_input, capital_structure = build_capital_input(refresh_demo=True)
run_stress_test(capital_input, capital_structure)
