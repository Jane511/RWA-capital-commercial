# %% [markdown]
# # 02 Calculate Expected Loss
# Apply the EL formula using `pd_12m`, `lgd_downturn`, and `ead_downturn`.

# %%
from src.calculate_el import add_expected_loss
from src.merge_inputs import build_capital_input

capital_input, _ = build_capital_input(refresh_demo=True)
add_expected_loss(capital_input).head()
