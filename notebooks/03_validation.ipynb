# %% [markdown]
# # 03 Validation
#
# Review the pipeline validation report and key reconciliations for `RWA-capital-commercial`.

# %%
from src.run_pipeline import run_pipeline

result = run_pipeline(persist=False, refresh_demo_inputs=True)
result["validation"]
