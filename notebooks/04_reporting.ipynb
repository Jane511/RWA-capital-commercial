# %% [markdown]
# # 04 Reporting
#
# Generate management-friendly capital summaries, segment views, and monitoring-linked bridge tables.

# %%
from src.run_pipeline import run_pipeline

result = run_pipeline(persist=False, refresh_demo_inputs=True)
result["outputs"]["monitoring_capital_bridge.csv"]
