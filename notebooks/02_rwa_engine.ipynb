# %% [markdown]
# # 02 RWA Engine
#
# Run the simplified capital-style engine and inspect facility-level RWA outputs.
#
# The repo uses transparent segment, product, and maturity assumptions rather than a production prudential formula set.

# %%
from src.run_pipeline import run_pipeline

result = run_pipeline(persist=False, refresh_demo_inputs=True)
result["outputs"]["rwa_by_facility.csv"].head()
